# %% [markdown]
# ### Table Processing
#
# We can also use textract output to perform structural changes - one such change is concatenation of tables that span more than one page. Doing this manually is tedious but we can use the postional information of tables as well as the header segmentations to detect which tables should be connected.
#
# <p align="center">
#   <img
#     src="assets/table_concatenation.png"
#     alt="Logo"
#     width="600"
#     style="height: auto;"
#   />
# </p>

# %%
import json

# %%
path_to_textract_json = "data/raw_textract_json/WO2020245233A1.json"
doc = json.load(open(path_to_textract_json, "r"))

# %%
from table_processing_utils import merge_document_tables_doc

tables = merge_document_tables_doc(doc)
